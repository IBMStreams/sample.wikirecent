# %%
""""
Send video, frame-by-frame to Kafka interface
- Frame is encoded into ascii so no one gets upset with the data.
- Frame will be decomposed into chunks of 'CHUNK_SIZE'. When debugging found Kafka would not send message if it went over threshold.
- Receiving test notebook VideoRcvKafka
- The Steams application VideoRcvKafka recieves the encode image and scores it with Model.

"""
import kafka
import os
import sys
import json
import base64
import ssl
import time
import datetime
import io
from PIL import Image
import logging
import cv2
import matplotlib.pyplot as plt
import numpy as np
if '../juypter' not in sys.path:
    sys.path.insert(0, '../juypter')
import credential
import streams_aid as aid

logging.basicConfig(level=os.environ.get("LOGLEVEL", "INFO"))
# img_encoded = str(base64.b64encode(response.content).decode("utf-8"))
# img_encoded = str(base64.b64encode(img).decode('utf-8'))


def bts_to_img(bts):
    buff = np.fromstring(bts, np.uint8)
    buff = buff.reshape(1, -1)
    img = cv2.imdecode(buff, cv2.IMREAD_COLOR)
    return img


def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


def encode_img(img):
    """must be easier way"""
    with io.BytesIO() as output:
        img.save(output, format="JPEG")
        contents = output.getvalue()
    return base64.b64encode(contents).decode('ascii')


def decode_img(bin64):
    """must be easier way"""
    img = Image.open(io.BytesIO(base64.b64decode(bin64)))
    return img


CHUNK_SIZE = 100000         # maximum number of bytes to transmit at a time

def video_kafka(video_url, kafka_prod, kafka_topic='VideoFrame', frame_modulo=24, send_wait=.25, debug=False):
    """Send video via Kafka

    :param video_url: url of video to pull in and send
    :param kafka_prod: the handle to sent out messages on kafka
    :param frame_modulo: send every x frames
    :param send_wait: after sending a frame wait time
    :param debug: decode image and write out to verify
    :return: None

    """
    frame_num = 0

    cap = cv2.VideoCapture(video_url)
    while(cap.isOpened()):
        ret, frame = cap.read()
        if ret is False:
            break
        frame_num += 1
        if not(frame_num % frame_modulo):
            image_encoded =encode_img(Image.fromarray(frame, 'RGB'))
            if debug:
                # debugging - render what we will send.
                img_raw = decode_img(image_encoded)
                plt.imshow(img_raw)
                plt.show()
            # break down frame into chunks
            chunks = [image_encoded[i * CHUNK_SIZE:(i + 1) * CHUNK_SIZE] for i in
                      range((len(image_encoded) + CHUNK_SIZE - 1) // CHUNK_SIZE)]
            # send the chunks.
            for idx, chunk in enumerate(chunks):
                logging.debug("chunking - {}  #chunks :{} idx:{} len(chunk):{}".format(video_url, len(chunks), idx, len(chunk)))
                chunk_content = {'video': video_url,
                       'frame': frame_num,
                       'chunk_idx':idx,
                       'chunk_total':len(chunks),
                       'timestamp': datetime.datetime.utcnow().isoformat() + 'Z',
                       'data': chunk
                }
                kafka_prod.send(kafka_topic, value=json.dumps(chunk_content).encode('utf-8'))
            ## finish the frame frame
            chunk_complete = {'video': video_url,
                   'frame': frame_num,
                    'chunk_idx': len(chunks),
                    'chunk_total': len(chunks),
                   'timestamp': datetime.datetime.utcnow().isoformat() + 'Z',
                   'data': ""
                   }
            logging.info("Transmit frame #{}".format(chunk_content["frame"]))
            kafka_prod.send(kafka_topic, value=json.dumps(chunk_complete).encode('utf-8'))
            time.sleep(send_wait)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
    return

def kafka_producer(credentials):
    """
    Open the connection to the kafka producer
    :param credentials:
    :return: kafka producer

    Request is responsilbe for closing producer.
    """
    prod = None
    while prod is None:
        try:
            prod = kafka.KafkaProducer(bootstrap_servers=credentials["kafka_brokers_sasl"],
                                       security_protocol="SASL_SSL",
                                       sasl_mechanism="PLAIN",
                                       sasl_plain_username=credentials["user"],
                                       sasl_plain_password=credentials["api_key"],
                                       ssl_cafile=ssl.get_default_verify_paths().cafile)

        except kafka.errors.NoBrokersAvailable:
            logging.warning("No Brokers Available. Retrying ...")
            time.sleep(1)
            prod = None
    return prod

# %%
"""
Selection of video use - 
 - Internet archive has many more.
"""

TOPIC="VideoFrame"

@aid.catchInterrupt
def videoStream(topic="VideoFrame", videoUrl="https://archive.org/download/popeye_shuteye_popeye/popeye_shuteye_popeye_512kb.mp4"):
    creds = json.loads(credential.magsEventStream)
    prod = kafka_producer(creds,)
    video_kafka(videoUrl, prod,  kafka_topic=topic, send_wait=1, frame_modulo=24)
    prod.close()
    
video_urls = [
'https://ia803104.us.archive.org/21/items/nwctc-Crystal_Airport_Changes_to_Move_Forward/Crystal_Airport_Changes_to_Move_Forward.mp4',
'https://ia801309.us.archive.org/12/items/ISS-Tours/ISS-Tour_Flight-day-highlights_DI_2015_007_1256_220882.mp4',
'https://ia802705.us.archive.org/14/items/KarlFriedrichDraisTheBicycle/Karl%20Friedrich%20Drais%20The%20Bicycle.mp4',
'https://ia800504.us.archive.org/30/items/doa_1949/doa_1949_512kb.mp4',
'https://archive.org/download/popeye_shuteye_popeye/popeye_shuteye_popeye_512kb.mp4',
'https://archive.org/download/MuhammadAliVsSonnyListon/MuhammadAliVsSonnyListon_512kb.mp4',
'https://archive.org/download/bb_snow_white/bb_snow_white_512kb.mp4',
]

videoStream(videoUrl=video_urls[3])
# Out:
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-4 host=broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <connecting> [IPv4 ('52.116.39.5', 9093)]>: connecting to broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 [('52.116.39.5', 9093) IPv4]
# INFO:kafka.conn:Probing node bootstrap-4 broker version
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-4 host=broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <handshake> [IPv4 ('52.116.39.5', 9093)]>: Loading SSL CA from /Users/siegenth/opt/anaconda3/envs/py36/ssl/cert.pem
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-4 host=broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <authenticating> [IPv4 ('52.116.39.5', 9093)]>: Authenticated as token via PLAIN
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-4 host=broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <authenticating> [IPv4 ('52.116.39.5', 9093)]>: Connection complete.
# INFO:kafka.conn:Broker version identifed as 1.0.0
# INFO:kafka.conn:Set configuration api_version=(1, 0, 0) to skip auto check_version requests on startup
# INFO:root:Transmit frame #24
# INFO:kafka.conn:<BrokerConnection node_id=0 host=broker-0-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <connecting> [IPv4 ('169.48.196.106', 9093)]>: connecting to broker-0-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 [('169.48.196.106', 9093) IPv4]
# INFO:kafka.conn:<BrokerConnection node_id=0 host=broker-0-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <handshake> [IPv4 ('169.48.196.106', 9093)]>: Loading SSL CA from /Users/siegenth/opt/anaconda3/envs/py36/ssl/cert.pem
# INFO:kafka.conn:<BrokerConnection node_id=0 host=broker-0-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <authenticating> [IPv4 ('169.48.196.106', 9093)]>: Authenticated as token via PLAIN
# INFO:kafka.conn:<BrokerConnection node_id=0 host=broker-0-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <authenticating> [IPv4 ('169.48.196.106', 9093)]>: Connection complete.
# INFO:kafka.conn:<BrokerConnection node_id=bootstrap-4 host=broker-3-qh451l9pr7s10q5v.kafka.svc01.us-south.eventstreams.cloud.ibm.com:9093 <connected> [IPv4 ('52.116.39.5', 9093)]>: Closing connection.
# INFO:root:Transmit frame #48
# INFO:root:Transmit frame #72
# INFO:root:Transmit frame #96
# INFO:root:Transmit frame #120
# INFO:root:Transmit frame #144
# INFO:root:Transmit frame #168
# INFO:root:Transmit frame #192
# INFO:root:Transmit frame #216
# INFO:root:Transmit frame #240
# INFO:root:Transmit frame #264
# INFO:root:Transmit frame #288
# INFO:root:Transmit frame #312
# INFO:root:Transmit frame #336
# INFO:root:Transmit frame #360
# INFO:root:Transmit frame #384
# INFO:root:Transmit frame #408
# INFO:root:Transmit frame #432
# INFO:root:Transmit frame #456
# INFO:root:Transmit frame #480
# INFO:root:Transmit frame #504
# INFO:root:Transmit frame #528
# INFO:root:Transmit frame #552
# INFO:root:Transmit frame #576
# INFO:root:Transmit frame #600
# INFO:root:Transmit frame #624
# INFO:root:Transmit frame #648
# INFO:root:Transmit frame #672
# INFO:root:Transmit frame #696
# INFO:root:Transmit frame #720
# INFO:root:Transmit frame #744
# INFO:root:Transmit frame #768
# INFO:root:Transmit frame #792
# INFO:root:Transmit frame #816
# INFO:root:Transmit frame #840
# INFO:root:Transmit frame #864
# INFO:root:Transmit frame #888
# INFO:root:Transmit frame #912
# INFO:root:Transmit frame #936
# INFO:root:Transmit frame #960
# INFO:root:Transmit frame #984
# INFO:root:Transmit frame #1008
# INFO:root:Transmit frame #1032
# INFO:root:Transmit frame #1056
# INFO:root:Transmit frame #1080
# INFO:root:Transmit frame #1104
# INFO:root:Transmit frame #1128
# INFO:root:Transmit frame #1152
# INFO:root:Transmit frame #1176
# INFO:root:Transmit frame #1200
# INFO:root:Transmit frame #1224
# INFO:root:Transmit frame #1248
# INFO:root:Transmit frame #1272
# INFO:root:Transmit frame #1296
# INFO:root:Transmit frame #1320
# INFO:root:Transmit frame #1344
# INFO:root:Transmit frame #1368
# INFO:root:Transmit frame #1392
# INFO:root:Transmit frame #1416
# INFO:root:Transmit frame #1440
# INFO:root:Transmit frame #1464
# INFO:root:Transmit frame #1488
# INFO:root:Transmit frame #1512
# INFO:root:Transmit frame #1536
# INFO:root:Transmit frame #1560
# INFO:root:Transmit frame #1584
# INFO:root:Transmit frame #1608
# INFO:root:Transmit frame #1632
# INFO:root:Transmit frame #1656
# INFO:root:Transmit frame #1680
# INFO:root:Transmit frame #1704
# INFO:root:Transmit frame #1728
# INFO:root:Transmit frame #1752
# INFO:root:Transmit frame #1776
# INFO:root:Transmit frame #1800
# INFO:root:Transmit frame #1824
# INFO:root:Transmit frame #1848
# INFO:root:Transmit frame #1872
# INFO:root:Transmit frame #1896
# INFO:root:Transmit frame #1920
# INFO:root:Transmit frame #1944
# INFO:root:Transmit frame #1968
# INFO:root:Transmit frame #1992
# INFO:root:Transmit frame #2016
# INFO:root:Transmit frame #2040
# INFO:root:Transmit frame #2064
# INFO:root:Transmit frame #2088
# INFO:root:Transmit frame #2112
# INFO:root:Transmit frame #2136
# INFO:root:Transmit frame #2160
# INFO:root:Transmit frame #2184
# INFO:root:Transmit frame #2208
# INFO:root:Transmit frame #2232
# INFO:root:Transmit frame #2256
# INFO:root:Transmit frame #2280
# INFO:root:Transmit frame #2304
# INFO:root:Transmit frame #2328
# INFO:root:Transmit frame #2352
# INFO:root:Transmit frame #2376
# INFO:root:Transmit frame #2400
# INFO:root:Transmit frame #2424
# INFO:root:Transmit frame #2448
# INFO:root:Transmit frame #2472
# INFO:root:Transmit frame #2496
# INFO:root:Transmit frame #2520
# INFO:root:Transmit frame #2544
# INFO:root:Transmit frame #2568
# INFO:root:Transmit frame #2592
# INFO:root:Transmit frame #2616
# INFO:root:Transmit frame #2640
# INFO:root:Transmit frame #2664
# INFO:root:Transmit frame #2688
# INFO:root:Transmit frame #2712
# INFO:root:Transmit frame #2736
# INFO:root:Transmit frame #2760
# INFO:root:Transmit frame #2784
# INFO:root:Transmit frame #2808
# INFO:root:Transmit frame #2832
# INFO:root:Transmit frame #2856
# INFO:root:Transmit frame #2880
# INFO:root:Transmit frame #2904
# INFO:root:Transmit frame #2928
# INFO:root:Transmit frame #2952
# INFO:root:Transmit frame #2976
# INFO:root:Transmit frame #3000
# INFO:root:Transmit frame #3024
# INFO:root:Transmit frame #3048
# INFO:root:Transmit frame #3072
# INFO:root:Transmit frame #3096
# INFO:root:Transmit frame #3120
# INFO:root:Transmit frame #3144
# INFO:root:Transmit frame #3168
# INFO:root:Transmit frame #3192
# INFO:root:Transmit frame #3216
# INFO:root:Transmit frame #3240
# INFO:root:Transmit frame #3264
# INFO:root:Transmit frame #3288
# INFO:root:Transmit frame #3312
# INFO:root:Transmit frame #3336
# INFO:root:Transmit frame #3360
# INFO:root:Transmit frame #3384
# INFO:root:Transmit frame #3408
# INFO:root:Transmit frame #3432
# INFO:root:Transmit frame #3456
# INFO:root:Transmit frame #3480
# INFO:root:Transmit frame #3504
# INFO:root:Transmit frame #3528
# INFO:root:Transmit frame #3552
# INFO:root:Transmit frame #3576
# INFO:root:Transmit frame #3600
# INFO:root:Transmit frame #3624
# INFO:root:Transmit frame #3648
# INFO:root:Transmit frame #3672
# INFO:root:Transmit frame #3696
# INFO:root:Transmit frame #3720
# INFO:root:Transmit frame #3744
# INFO:root:Transmit frame #3768
# INFO:root:Transmit frame #3792
# INFO:root:Transmit frame #3816
# INFO:root:Transmit frame #3840
# INFO:root:Transmit frame #3864
# INFO:root:Transmit frame #3888
# INFO:root:Transmit frame #3912
# INFO:root:Transmit frame #3936
# INFO:root:Transmit frame #3960
# INFO:root:Transmit frame #3984
# INFO:root:Transmit frame #4008
# INFO:root:Transmit frame #4032
# INFO:root:Transmit frame #4056
# INFO:root:Transmit frame #4080
# INFO:root:Transmit frame #4104
# INFO:root:Transmit frame #4128
# INFO:root:Transmit frame #4152
# INFO:root:Transmit frame #4176
# INFO:root:Transmit frame #4200
# INFO:root:Transmit frame #4224
# INFO:root:Transmit frame #4248
# INFO:root:Transmit frame #4272
# INFO:root:Transmit frame #4296
# INFO:root:Transmit frame #4320
# INFO:root:Transmit frame #4344
# INFO:root:Transmit frame #4368
# INFO:root:Transmit frame #4392
# INFO:root:Transmit frame #4416
# INFO:root:Transmit frame #4440
# INFO:root:Transmit frame #4464
# INFO:root:Transmit frame #4488
# INFO:root:Transmit frame #4512
# INFO:root:Transmit frame #4536
# INFO:root:Transmit frame #4560
# INFO:root:Transmit frame #4584
# INFO:root:Transmit frame #4608
# INFO:root:Transmit frame #4632
# INFO:root:Transmit frame #4656
# INFO:root:Transmit frame #4680
# INFO:root:Transmit frame #4704
# INFO:root:Transmit frame #4728
# INFO:root:Transmit frame #4752
# INFO:root:Transmit frame #4776
# INFO:root:Transmit frame #4800
# INFO:root:Transmit frame #4824
# INFO:root:Transmit frame #4848
# INFO:root:Transmit frame #4872
# INFO:root:Transmit frame #4896
# INFO:root:Transmit frame #4920
# INFO:root:Transmit frame #4944
# INFO:root:Transmit frame #4968
# INFO:root:Transmit frame #4992
# INFO:root:Transmit frame #5016
# INFO:root:Transmit frame #5040
# INFO:root:Transmit frame #5064
# INFO:root:Transmit frame #5088
# INFO:root:Transmit frame #5112
# INFO:root:Transmit frame #5136
# INFO:root:Transmit frame #5160
# INFO:root:Transmit frame #5184
# INFO:root:Transmit frame #5208
# INFO:root:Transmit frame #5232
# INFO:root:Transmit frame #5256
# INFO:root:Transmit frame #5280
# INFO:root:Transmit frame #5304
# INFO:root:Transmit frame #5328
# INFO:root:Transmit frame #5352
# INFO:root:Transmit frame #5376
# INFO:root:Transmit frame #5400
# INFO:root:Transmit frame #5424
# INFO:root:Transmit frame #5448
# INFO:root:Transmit frame #5472
# INFO:root:Transmit frame #5496
# INFO:root:Transmit frame #5520
# INFO:root:Transmit frame #5544
# INFO:root:Transmit frame #5568
# INFO:root:Transmit frame #5592
# INFO:root:Transmit frame #5616
# INFO:root:Transmit frame #5640
# INFO:root:Transmit frame #5664
# INFO:root:Transmit frame #5688
# INFO:root:Transmit frame #5712
# INFO:root:Transmit frame #5736
# INFO:root:Transmit frame #5760
# INFO:root:Transmit frame #5784
# INFO:root:Transmit frame #5808
# INFO:root:Transmit frame #5832
# INFO:root:Transmit frame #5856
# INFO:root:Transmit frame #5880
# INFO:root:Transmit frame #5904
# INFO:root:Transmit frame #5928
# INFO:root:Transmit frame #5952
# INFO:root:Transmit frame #5976
# INFO:root:Transmit frame #6000
# INFO:root:Transmit frame #6024
# INFO:root:Transmit frame #6048
# INFO:root:Transmit frame #6072
# INFO:root:Transmit frame #6096
# INFO:root:Transmit frame #6120
# INFO:root:Transmit frame #6144
# INFO:root:Transmit frame #6168
# INFO:root:Transmit frame #6192
# INFO:root:Transmit frame #6216
# INFO:root:Transmit frame #6240
# INFO:root:Transmit frame #6264
# INFO:root:Transmit frame #6288
# INFO:root:Transmit frame #6312
# INFO:root:Transmit frame #6336
# INFO:root:Transmit frame #6360
# INFO:root:Transmit frame #6384
# INFO:root:Transmit frame #6408
# INFO:root:Transmit frame #6432
# INFO:root:Transmit frame #6456
# INFO:root:Transmit frame #6480
# INFO:root:Transmit frame #6504
# INFO:root:Transmit frame #6528
# INFO:root:Transmit frame #6552
# INFO:root:Transmit frame #6576
# INFO:root:Transmit frame #6600
# INFO:root:Transmit frame #6624
# INFO:root:Transmit frame #6648
# INFO:root:Transmit frame #6672
# INFO:root:Transmit frame #6696
# INFO:root:Transmit frame #6720
# INFO:root:Transmit frame #6744
# INFO:root:Transmit frame #6768
# INFO:root:Transmit frame #6792
# INFO:root:Transmit frame #6816
# INFO:root:Transmit frame #6840
# INFO:root:Transmit frame #6864
# INFO:root:Transmit frame #6888
# INFO:root:Transmit frame #6912
# INFO:root:Transmit frame #6936
# INFO:root:Transmit frame #6960
# INFO:root:Transmit frame #6984
# INFO:root:Transmit frame #7008
# INFO:root:Transmit frame #7032
# INFO:root:Transmit frame #7056
# INFO:root:Transmit frame #7080
# INFO:root:Transmit frame #7104
# INFO:root:Transmit frame #7128
# INFO:root:Transmit frame #7152
# INFO:root:Transmit frame #7176
# INFO:root:Transmit frame #7200
# INFO:root:Transmit frame #7224
# INFO:root:Transmit frame #7248
# INFO:root:Transmit frame #7272
# INFO:root:Transmit frame #7296
# INFO:root:Transmit frame #7320
# INFO:root:Transmit frame #7344
# INFO:root:Transmit frame #7368
# INFO:root:Transmit frame #7392
# INFO:root:Transmit frame #7416
# INFO:root:Transmit frame #7440
# INFO:root:Transmit frame #7464
# INFO:root:Transmit frame #7488
# INFO:root:Transmit frame #7512
# INFO:root:Transmit frame #7536
# INFO:root:Transmit frame #7560
# INFO:root:Transmit frame #7584
# INFO:root:Transmit frame #11904
# INFO:root:Transmit frame #11928
# INFO:root:Transmit frame #11952
# INFO:root:Transmit frame #11976
# INFO:root:Transmit frame #12000
# INFO:root:Transmit frame #12024
# INFO:root:Transmit frame #12048
# INFO:root:Transmit frame #12072
# INFO:root:Transmit frame #12096
# INFO:root:Transmit frame #12120
# INFO:root:Transmit frame #12144
# INFO:root:Transmit frame #12168
# INFO:root:Transmit frame #12192
# INFO:root:Transmit frame #12216
# INFO:root:Transmit frame #12240
# INFO:root:Transmit frame #12264
# INFO:root:Transmit frame #12288
# INFO:root:Transmit frame #12312
# INFO:root:Transmit frame #12336
# INFO:root:Transmit frame #12360
# INFO:root:Transmit frame #12384
# INFO:root:Transmit frame #12408
# INFO:root:Transmit frame #12432
# INFO:root:Transmit frame #12456
# INFO:root:Transmit frame #12480
# INFO:root:Transmit frame #12504
# INFO:root:Transmit frame #12528
# INFO:root:Transmit frame #12552
# INFO:root:Transmit frame #12576
# INFO:root:Transmit frame #12600
# INFO:root:Transmit frame #12624
# INFO:root:Transmit frame #12648
# INFO:root:Transmit frame #12672
# INFO:root:Transmit frame #12696
# INFO:root:Transmit frame #12720
# INFO:root:Transmit frame #12744
# INFO:root:Transmit frame #12768
# INFO:root:Transmit frame #12792
# INFO:root:Transmit frame #12816
# INFO:root:Transmit frame #12840
# INFO:root:Transmit frame #12864
# INFO:root:Transmit frame #12888
# INFO:root:Transmit frame #12912
# INFO:root:Transmit frame #12936
# INFO:root:Transmit frame #12960
# INFO:root:Transmit frame #12984
# INFO:root:Transmit frame #13008
# INFO:root:Transmit frame #13032
# INFO:root:Transmit frame #13056
# INFO:root:Transmit frame #13080
# INFO:root:Transmit frame #13104
# INFO:root:Transmit frame #13128
# INFO:root:Transmit frame #13152
# INFO:root:Transmit frame #13176
# INFO:root:Transmit frame #13200
# INFO:root:Transmit frame #13224
# INFO:root:Transmit frame #13248
# INFO:root:Transmit frame #13272
# INFO:root:Transmit frame #13296
# INFO:root:Transmit frame #13320
# INFO:root:Transmit frame #13344
# INFO:root:Transmit frame #13368
# INFO:root:Transmit frame #13392
# INFO:root:Transmit frame #13416
# INFO:root:Transmit frame #13440
# INFO:root:Transmit frame #13464
# INFO:root:Transmit frame #13488
# INFO:root:Transmit frame #13512
# INFO:root:Transmit frame #13536
# INFO:root:Transmit frame #13560
# INFO:root:Transmit frame #13584
# INFO:root:Transmit frame #13608
# INFO:root:Transmit frame #13632
# INFO:root:Transmit frame #13656
# INFO:root:Transmit frame #13680
# INFO:root:Transmit frame #13704
# INFO:root:Transmit frame #13728
# INFO:root:Transmit frame #13752
# INFO:root:Transmit frame #13776
# INFO:root:Transmit frame #13800
# INFO:root:Transmit frame #13824
# INFO:root:Transmit frame #13848
# INFO:root:Transmit frame #13872
# INFO:root:Transmit frame #13896
# INFO:root:Transmit frame #13920
# INFO:root:Transmit frame #13944
# INFO:root:Transmit frame #13968
# INFO:root:Transmit frame #13992
# INFO:root:Transmit frame #14016
# INFO:root:Transmit frame #14040
# INFO:root:Transmit frame #16224
# INFO:root:Transmit frame #16248
# INFO:root:Transmit frame #16272
# INFO:root:Transmit frame #16296
# INFO:root:Transmit frame #16320
# INFO:root:Transmit frame #16344
# INFO:root:Transmit frame #16368
# INFO:root:Transmit frame #16392
# INFO:root:Transmit frame #16416
# INFO:root:Transmit frame #16440
# INFO:root:Transmit frame #16464
# INFO:root:Transmit frame #16488
# INFO:root:Transmit frame #16512
# INFO:root:Transmit frame #16536
# INFO:root:Transmit frame #16560
# INFO:root:Transmit frame #16584
# INFO:root:Transmit frame #16608
# INFO:root:Transmit frame #16632
# INFO:root:Transmit frame #16656
# INFO:root:Transmit frame #16680
# INFO:root:Transmit frame #16704
# INFO:root:Transmit frame #16728
# INFO:root:Transmit frame #16752
# INFO:root:Transmit frame #16776
# INFO:root:Transmit frame #16800
# INFO:root:Transmit frame #16824
# INFO:root:Transmit frame #16848
# INFO:root:Transmit frame #16872
# INFO:root:Transmit frame #16896
# INFO:root:Transmit frame #16920
# INFO:root:Transmit frame #16944
# INFO:root:Transmit frame #16968
# INFO:root:Transmit frame #16992
# INFO:root:Transmit frame #17016
# INFO:root:Transmit frame #17040
# INFO:root:Transmit frame #17064
# INFO:root:Transmit frame #17088
# INFO:root:Transmit frame #17112
# INFO:root:Transmit frame #17136
# INFO:root:Transmit frame #17160
# INFO:root:Transmit frame #17184
# INFO:root:Transmit frame #17208
# INFO:root:Transmit frame #17232
# INFO:root:Transmit frame #17256
# INFO:root:Transmit frame #17280
# INFO:root:Transmit frame #17304
# INFO:root:Transmit frame #17328
# INFO:root:Transmit frame #17352
# INFO:root:Transmit frame #17376
# INFO:root:Transmit frame #17400
# INFO:root:Transmit frame #17424
# INFO:root:Transmit frame #17448
# INFO:root:Transmit frame #17472
# INFO:root:Transmit frame #17496
# INFO:root:Transmit frame #17520
# INFO:root:Transmit frame #17544
# INFO:root:Transmit frame #17568
# INFO:root:Transmit frame #17592
# INFO:root:Transmit frame #17616
# INFO:root:Transmit frame #17640
# INFO:root:Transmit frame #17664
# INFO:root:Transmit frame #17688
# INFO:root:Transmit frame #17712
# INFO:root:Transmit frame #17736
# INFO:root:Transmit frame #17760
# INFO:root:Transmit frame #17784
# INFO:root:Transmit frame #17808
# INFO:root:Transmit frame #17832
# INFO:root:Transmit frame #17856
# INFO:root:Transmit frame #17880
# INFO:root:Transmit frame #17904
# INFO:root:Transmit frame #17928
# INFO:root:Transmit frame #17952
# INFO:root:Transmit frame #17976
# INFO:root:Transmit frame #18000
# INFO:root:Transmit frame #18024
# INFO:root:Transmit frame #18048
# INFO:root:Transmit frame #18072
# INFO:root:Transmit frame #18096
# INFO:root:Transmit frame #18120
# INFO:root:Transmit frame #18144
# INFO:root:Transmit frame #18168
# INFO:root:Transmit frame #18192
# INFO:root:Transmit frame #18216
# INFO:root:Transmit frame #18240
# INFO:root:Transmit frame #18264
# INFO:root:Transmit frame #18288
# INFO:root:Transmit frame #18312
# INFO:root:Transmit frame #18336
# INFO:root:Transmit frame #18360
